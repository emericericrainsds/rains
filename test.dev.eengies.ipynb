# %% [markdown]
# <a href="https://colab.research.google.com/github/emericericrainsds/rains/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount dev.eengies google drive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/DataScienTest/rains
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/DataScienTest/rains

# %%
import pandas as pd

df = pd.read_csv('input/rains.csv')
df.head()
# Out:
#          Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01  Newcastle     13.2      NaN       0.0          NaN       NaN
# 1  2008-12-02  Newcastle      NaN     32.2       0.0          NaN       NaN
# 2  2008-12-03  Newcastle     16.2     32.2       0.0          NaN       NaN
# 3  2008-12-04  Newcastle     19.2     24.0       0.0          NaN       NaN
# 4  2008-12-05  Newcastle     18.8     30.2       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0         NaN            NaN         NW  ...        50.0         24.0
# 1         NaN            NaN        NaN  ...         NaN         59.0
# 2         NaN            NaN          N  ...        74.0         26.0
# 3         NaN            NaN         SE  ...        66.0         61.0
# 4         NaN            NaN         NE  ...        85.0          NaN
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...
